# %%
import pandas as pd
import sqlalchemy as db
from matplotlib import pyplot as plt
import seaborn as sns
import functions as f
import statsmodels.formula.api as smf
import numpy as np

# %matplotlib inline

# %%
engine = db.create_engine('sqlite:///stocks_formatted.db')

# %%
df_prices = pd.read_sql_table('price_close', con=engine)

# %%
jaccard_df = pd.read_csv('jaccard.csv')

# %%
jaccard_df.drop(columns=['Unnamed: 0'],inplace=True)

# %% [markdown]
# clean jaccard scoere table

# %%
jaccard_df['Symbol'] = jaccard_df['0'].apply(lambda x: x.split()[0])

# %%
jaccard_df['Symbol'] = jaccard_df['Symbol'].apply(lambda x: x[2:-2])

# %%
jaccard_df['Year'] = jaccard_df['0'].apply(lambda x: x.split()[1])

# %%
jaccard_df['Year'] = jaccard_df['Year'].apply(lambda x: x[:-1])

# %%
jaccard_df.drop(columns = ['0'],inplace=True)

# %%
jaccard_df.columns = ['jaccard_score', 'symbol', 'year']

# %%
jaccard_df.set_index('symbol', inplace=True)

# %% [markdown]
# calculate 8 month percentagre change in price from jan

# %%
df_prices.set_index('date', inplace=True)
df_prices.drop(columns=['index'], inplace=True)

# %%
df_prices.tail()
# Out:
#                MMM    AOS    ABT   ABBV    ACN    ATVI     AYI   ADBE     AAP  \
# date
# 2014-01-09  136.45  52.48  39.27  51.22  82.95  18.300  123.50  59.09  113.55
# 2014-01-08  136.63  52.15  39.20  50.36  82.15  18.340  110.03  58.90  112.30
# 2014-01-07  137.65  52.75  38.85  50.49  81.52  18.315  109.44  58.97  113.18
# 2014-01-06  137.63  53.27  39.15  50.39  80.54  18.080  106.28  58.12  111.80
# 2014-01-03  138.45  53.31  38.64  52.30  81.40  18.290  108.15  59.16  112.88
#
#              AMD  ...     WU     WY     WHR    WMB    WYNN    XEL    XRX  \
# date              ...
# 2014-01-09  4.09  ...  17.06  31.00  159.01  39.25  204.77  27.82  12.05
# 2014-01-08  4.18  ...  17.42  30.82  157.60  39.16  205.29  27.71  12.08
# 2014-01-07  4.18  ...  17.44  31.11  154.58  39.01  201.51  27.82  12.19
# 2014-01-06  4.13  ...  17.06  31.02  154.45  38.40  195.86  27.35  12.09
# 2014-01-03  4.00  ...  16.92  31.34  156.90  38.03  196.00  27.50  11.99
#
#              XLNX    XYL    YUM
# date
# 2014-01-09  45.78  34.63  75.05
# 2014-01-08  45.91  34.49  76.53
# 2014-01-07  45.52  34.51  76.56
# 2014-01-06  45.42  34.41  75.50
# 2014-01-03  45.62  34.47  75.56
#
# [5 rows x 459 columns]

# %%
df_returns = f.transform_to_august_returns(df_prices)

# %%
for col in df_returns.columns:
    sns.kdeplot(df_returns[col])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-f44cbdd66e70> in <module>
#       1 for col in df_returns.columns:
# ----> 2     sns.kdeplot(df_returns[col])
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     651         return ax
#     652
# --> 653     data = data.astype(np.float64)
#     654     if data2 is not None:
#     655         if isinstance(data2, list):
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     700     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     701         # Explicit copy, or required since NumPy can't view from / to object.
# --> 702         return arr.astype(dtype, copy=True)
#     703
#     704     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'Agilent Technologies, Inc.'

# %%
sp_500_df = pd.read_csv('sp500_daily.csv')

# %%
sp_500_df.set_index(['Date'], inplace= True)

# %%
sp_500_df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-01-03  1833.209961  1838.239990  1829.130005  1831.369995  1831.369995
# 2014-01-06  1832.310059  1837.160034  1823.729980  1826.770020  1826.770020
# 2014-01-07  1828.709961  1840.099976  1828.709961  1837.880005  1837.880005
# 2014-01-08  1837.900024  1840.020020  1831.400024  1837.489990  1837.489990
# 2014-01-09  1839.000000  1843.229980  1830.380005  1838.130005  1838.130005
#
#                 Volume
# Date
# 2014-01-03  2774270000
# 2014-01-06  3294850000
# 2014-01-07  3511750000
# 2014-01-08  3652140000
# 2014-01-09  3581150000

# %%
nasdaq = pd.read_csv('csv/NASDAQ.csv')
amex = pd.read_csv('csv/AMEX.csv')
nyse = pd.read_csv('csv/NYSE.csv')

# %%
df = pd.concat([nasdaq, amex, nyse])

# %%
df.set_index('Symbol', inplace = True)

# %%
df.drop(columns = ['LastSale', 'IPOyear', 'Unnamed: 8', 'Summary Quote'], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# Name         object
# MarketCap    object
# Sector       object
# industry     object
# dtype: object

# %%
#transform market cap 
df['MarketCap'] = df['MarketCap'].apply(lambda x: x[1:-2])

# %%
df.MarketCap = pd.to_numeric(df.MarketCap)

# %%
df.MarketCap = np.log(df.MarketCap)

# %%
df.MarketCap.head()
# Out:
# Symbol
# YI       6.013960
# PIH      1.098612
# PIHPP    2.862201
# TURN     4.104295
# FLWS     0.182322
# Name: MarketCap, dtype: float64

# %%
df_returns = df_returns.join(df, how='left')

# %%
df_returns = df_returns.join(pd.get_dummies(df_returns.Sector), how='left')

# %%
df_returns.head()
# Out:
#           2014      2015      2016      2017      2018      2019  \
# A     0.023366 -0.032051  0.096092  0.271886 -0.090680  0.153600
# AAL   0.652600 -0.280282 -0.283060  0.088337 -0.276090  0.012315
# AAP   0.191797  0.025795  0.079414 -0.305920  0.269677 -0.008422
# AAPL -0.827129  0.157962 -0.089796  0.235471  0.086613  0.276279
# ABBV  0.087763  0.039763  0.088526  0.160391 -0.053856 -0.177407
#
#                                Name  MarketCap             Sector  \
# A        Agilent Technologies, Inc.   3.139833      Capital Goods
# AAL   American Airlines Group, Inc.   2.681022     Transportation
# AAP          Advance Auto Parts Inc   2.415914  Consumer Services
# AAPL                     Apple Inc.   6.840547         Technology
# ABBV                    AbbVie Inc.   4.662495        Health Care
#
#                                               industry  ...  \
# A     Biotechnology: Laboratory Analytical Instruments  ...
# AAL                      Air Freight/Delivery Services  ...
# AAP                             Other Specialty Stores  ...
# AAPL                            Computer Manufacturing  ...
# ABBV                             Major Pharmaceuticals  ...
#
#       Consumer Durables  Consumer Non-Durables  Consumer Services  Energy  \
# A                     0                      0                  0       0
# AAL                   0                      0                  0       0
# AAP                   0                      0                  1       0
# AAPL                  0                      0                  0       0
# ABBV                  0                      0                  0       0
#
#       Finance  Health Care  Miscellaneous  Public Utilities  Technology  \
# A           0            0              0                 0           0
# AAL         0            0              0                 0           0
# AAP         0            0              0                 0           0
# AAPL        0            0              0                 0           1
# ABBV        0            1              0                 0           0
#
#       Transportation
# A                  0
# AAL                1
# AAP                0
# AAPL               0
# ABBV               0
#
# [5 rows x 22 columns]

# %%
df = df_returns.join(jaccard_df, how='left')

# %%
df.dropna(inplace = True)

# %%
sns.distplot(df['jaccard_score'])
plt.savefig("jaccard hist.png")

# %%
type(list(pd.qcut(df.jaccard_score, 5).unique())[0])
# Out:
# pandas._libs.interval.Interval

# %%
quint_dict = {}
x = [3,5,4,2,1]
for i, j in enumerate(list(pd.qcut(df.jaccard_score, 5).unique())):
    quint_dict[j] = x[i] 
quint_dict
# Out:
# {Interval(0.0272, 0.0324, closed='right'): 3,
#  Interval(0.0378, 0.0588, closed='right'): 5,
#  Interval(0.0324, 0.0378, closed='right'): 4,
#  Interval(0.00044000000000000007, 0.0213, closed='right'): 2,
#  Interval(0.0213, 0.0272, closed='right'): 1}

# %%
dummy_frame = pd.DataFrame(pd.qcut(df.jaccard_score, 5))

# %%
dummy_frame.head()
# Out:
#                          jaccard_score
# FB                    (0.0272, 0.0324]
# FBHS                  (0.0378, 0.0588]
# FBHS                  (0.0324, 0.0378]
# FCX   (0.00044000000000000007, 0.0213]
# FCX   (0.00044000000000000007, 0.0213]

# %%
dummy_frame['jaccard_quintiles'] = dummy_frame['jaccard_score'].apply(lambda x: quint_dict[x])

# %%
df = df.join(pd.get_dummies(dummy_frame['jaccard_quintiles']), how='left')

# %%
df
# Out:
#           2014      2015      2016      2017      2018      2019  \
# FB    0.247503  0.107839  0.117100  0.270152  0.087862  0.422465
# FBHS -0.113646  0.026345  0.058673  0.213769 -0.223451  0.491948
# FBHS -0.113646  0.026345  0.058673  0.213769 -0.223451  0.491948
# FBHS -0.113646  0.026345  0.058673  0.213769 -0.223451  0.491948
# FBHS -0.113646  0.026345  0.058673  0.213769 -0.223451  0.491948
# FCX  -0.012594 -0.218684  0.732824 -0.114659 -0.132018  0.105212
# FCX  -0.012594 -0.218684  0.732824 -0.114659 -0.132018  0.105212
# FCX  -0.012594 -0.218684  0.732824 -0.114659 -0.132018  0.105212
# FCX  -0.012594 -0.218684  0.732824 -0.114659 -0.132018  0.105212
# FDX   0.088040 -0.015309  0.072579  0.158125 -0.109511 -0.001348
# FE    0.062168 -0.163010  0.115238 -0.061066  0.175211  0.163943
# FE    0.062168 -0.163010  0.115238 -0.061066  0.175211  0.163943
# XRAY                          DENTSPLY SIRONA Inc.   2.564949
# XRX                              Xerox Corporation   2.066863
# XRX                              Xerox Corporation   2.066863
# XRX                              Xerox Corporation   2.066863
# XRX                              Xerox Corporation   2.066863
# XYL                                     Xylem Inc.   2.667228
# XYL                                     Xylem Inc.   2.667228
# XYL                                     Xylem Inc.   2.667228
# XYL                                     Xylem Inc.   2.667228
# YUM                              Yum! Brands, Inc.   3.523415
# YUM                              Yum! Brands, Inc.   3.523415
# YUM                              Yum! Brands, Inc.   3.523415
# YUM                              Yum! Brands, Inc.   3.523415
#
#                  Sector                                         industry  ...  \
# FB           Technology  Computer Software: Programming, Data Processing  ...
# FBHS   Basic Industries                                     Homebuilding  ...
# FBHS   Basic Industries                                     Homebuilding  ...
# FBHS   Basic Industries                                     Homebuilding  ...
# FBHS   Basic Industries                                     Homebuilding  ...
# FCX    Basic Industries                                  Precious Metals  ...
# FCX    Basic Industries                                  Precious Metals  ...
# FCX    Basic Industries                                  Precious Metals  ...
# FCX    Basic Industries                                  Precious Metals  ...
# FDX      Transportation                    Air Freight/Delivery Services  ...
# FE     Public Utilities                      Electric Utilities: Central  ...
# FE     Public Utilities                      Electric Utilities: Central  ...
# FE     Public Utilities                      Electric Utilities: Central  ...
# FE     Public Utilities                      Electric Utilities: Central  ...
# FFIV         Technology                Computer Communications Equipment  ...
# FIS       Miscellaneous                                Business Services  ...
# FIS       Miscellaneous                                Business Services  ...
# FIS       Miscellaneous                                Business Services  ...
# FIS       Miscellaneous                                Business Services  ...
# FISV         Technology                                     EDP Services  ...
# FISV         Technology                                     EDP Services  ...
# FISV         Technology                                     EDP Services  ...
# FISV         Technology                                     EDP Services  ...
# FITB            Finance                                      Major Banks  ...
# FITB            Finance                                      Major Banks  ...
# FITB            Finance                                      Major Banks  ...
# FITB            Finance                                      Major Banks  ...
# FL    Consumer Services                   Clothing/Shoe/Accessory Stores  ...
# FL    Consumer Services                   Clothing/Shoe/Accessory Stores  ...
# FL    Consumer Services                   Clothing/Shoe/Accessory Stores  ...
# ...                 ...                                              ...  ...
# XEC              Energy                             Oil & Gas Production  ...
# XEC              Energy                             Oil & Gas Production  ...
# XEL    Public Utilities                                 Power Generation  ...
# XEL    Public Utilities                                 Power Generation  ...
# XEL    Public Utilities                                 Power Generation  ...
# XEL    Public Utilities                                 Power Generation  ...
# XLNX         Technology                                   Semiconductors  ...
# XLNX         Technology                                   Semiconductors  ...
# XLNX         Technology                                   Semiconductors  ...
# XLNX         Technology                                   Semiconductors  ...
# XOM              Energy                         Integrated oil Companies  ...
# XOM              Energy                         Integrated oil Companies  ...
# XOM              Energy                         Integrated oil Companies  ...
# XOM              Energy                         Integrated oil Companies  ...
# XRAY        Health Care                       Medical/Dental Instruments  ...
# XRAY        Health Care                       Medical/Dental Instruments  ...
# XRAY        Health Care                       Medical/Dental Instruments  ...
# XRAY        Health Care                       Medical/Dental Instruments  ...
# XRX          Technology                    Computer peripheral equipment  ...
# XRX                  0           1               0       0.026064  2018  0  1
# XRX                  0           1               0       0.026064  2018  0  1
# XRX                  0           1               0       0.025333  2019  0  1
# XRX                  0           1               0       0.025333  2019  0  1
# XYL                  0           0               0       0.024510  2018  0  1
# XYL                  0           0               0       0.024510  2018  1  0
# XYL                  0           0               0       0.018223  2019  0  1
# XYL                  0           0               0       0.018223  2019  1  0
# YUM                  0           0               0       0.022485  2018  0  1
# YUM                  0           0               0       0.022485  2018  0  1
# YUM                  0           0               0       0.021436  2019  0  1
# YUM                  0           0               0       0.021436  2019  0  1
#
#       3  4  5
# FB    1  0  0
# FBHS  0  0  1
# FBHS  0  1  0
# FBHS  0  0  1
# FBHS  0  1  0
# FCX   0  0  0
# FCX   0  0  0
# FCX   0  0  0
# FCX   0  0  0
# FDX   0  0  0
# FE    0  0  0
# FE    0  0  0
# FE    0  0  0
# FE    0  0  0
# FFIV  0  0  1
# FIS   0  0  1
# FIS   0  1  0
# FIS   0  0  1
# FIS   0  1  0
# FISV  0  0  1
# FISV  0  0  1
# FISV  0  0  1
# FISV  0  0  1
# FITB  0  0  0
# FITB  0  0  0
# FITB  0  0  0
# FITB  0  0  0
# FL    1  0  0
# FL    1  0  0
# FL    1  0  0
# ...  .. .. ..
# XEC   0  1  0
# XEC   0  1  0
# XEL   0  0  0
# XEL   0  0  0
# XEL   0  0  0
# XEL   0  0  0
# XLNX  0  0  1
# XLNX  0  1  0
# XLNX  0  0  1
# XLNX  0  1  0
# XOM   0  0  0
# XOM   0  0  0
# XOM   0  0  0
# XOM   0  0  0
# XRAY  1  0  0
# XRAY  0  0  0
# XRAY  1  0  0
# XRAY  0  0  0
# XRX   0  0  0
# XRX   0  0  0
# XRX   0  0  0
# XRX   0  0  0
# XYL   0  0  0
# XYL   0  0  0
# XYL   0  0  0
# XYL   0  0  0
# YUM   0  0  0
# YUM   0  0  0
# YUM   0  0  0
# YUM   0  0  0
#
# [1085 rows x 29 columns]

# %%
df['returns'] = (df['2019'])

# %%
df_2018 = df[df.year == '2018']
df_2019 = df[df.year == '2019']

# %%
df_lowjaccard = df_2019[df_2019.jaccard_score <= df_2019.jaccard_score.quantile(0.10)]['2019']

# %%
df_lowjaccard.hist()

# %%
df_highjaccard = df_2019[df_2019.jaccard_score >= df_2019.jaccard_score.quantile(0.20)]['2019']

# %%
df_highjaccard.mean()
# Out:
# 0.1658665850889137

# %%
df['2019'].mean()
# Out:
# 0.1729856023259516

# %%
df_2019.returns
# Out:
# FB      0.422465
# FBHS    0.491948
# FBHS    0.491948
# FCX     0.105212
# FCX     0.105212
# FE      0.163943
# FE      0.163943
# FIS     0.228138
# FIS     0.228138
# FISV    0.281124
# FISV    0.281124
# FITB    0.170248
# FITB    0.170248
# FL     -0.199583
# FL     -0.199583
# FLIR    0.256208
# FLIR    0.256208
# FLR     0.011840
# FLR     0.011840
# FLS     0.399581
# FLS     0.399581
# FMC     0.132676
# FMC     0.132676
# FRT     0.105863
# FRT     0.105863
# FTI     0.307731
# FTI     0.307731
# GD      0.160753
# GD      0.160753
# GE      0.320497
#           ...
# WFC     0.015978
# WFC     0.015978
# WM      0.299482
# WM      0.299482
# WMB     0.251561
# WMB     0.251561
# WMT     0.185130
# WMT     0.185130
# WU      0.165694
# WU      0.165694
# WY      0.226196
# WY      0.226196
# WYNN    0.257184
# WYNN    0.257184
# XEC    -0.042417
# XEC    -0.042417
# XEL     0.232476
# XEL     0.232476
# XLNX    0.394934
# XLNX    0.394934
# XOM     0.098579
# XOM     0.098579
# XRAY    0.539192
# XRAY    0.539192
# XRX     0.800298
# XRX     0.800298
# XYL     0.269132
# XYL     0.269132
# YUM     0.197397
# YUM     0.197397
# Name: returns, Length: 525, dtype: float64

# %%
In [1]: import statsmodels.api as sm

# %%
f = 'returns~+Q(2)+Q(3)+Q(4)+Q(5)'
model = smf.ols(f, data=df).fit()
Table = sm.stats.anova_lm(model, typ=2)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.421
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):              0.225
# Time:                        15:13:48   Log-Likelihood:                 370.99
# No. Observations:                1085   AIC:                            -732.0
# Df Residuals:                    1080   BIC:                            -707.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1545      0.012     12.874      0.000       0.131       0.178
# Q(2)           0.0328      0.017      1.952      0.051      -0.000       0.066
# Q(3)           0.0084      0.017      0.496      0.620      -0.025       0.042
# Q(4)           0.0186      0.017      1.123      0.261      -0.014       0.051
# Q(5)           0.0306      0.017      1.846      0.065      -0.002       0.063
# ==============================================================================
# Omnibus:                       40.374   Durbin-Watson:                   0.549
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.404
# Skew:                          -0.265   Prob(JB):                     6.97e-17
# Kurtosis:                       4.168   Cond. No.                         5.97
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(Table)
# Out:
#              sum_sq      df         F    PR(>F)
# Q(2)       0.113100     1.0  3.809970  0.051207
# Q(3)       0.007312     1.0  0.246331  0.619772
# Q(4)       0.037469     1.0  1.262200  0.261485
# Q(5)       0.101187     1.0  3.408668  0.065128
# Residual  32.060078  1080.0       NaN       NaN

# %%
smean = df_lowjaccard

# %%
from scipy import stats

# %%
stats.ttest_1samp(a=smean, popmean= df_2019.jaccard_score.mean())

# %%
stats.ttest_1samp(a=smean, popmean= df_2019.jaccard_score.mean())
# Out:
# Ttest_1sampResult(statistic=8.715639170451011, pvalue=8.191741499293817e-12)

# %%
(df['2019'].mean() - smean.mean())/df['2019'].mean()
# Out:
# -0.10234521882195527

# %%
df_low2018 = df_2018[df_2018.jaccard_score<=df_2018.jaccard_score.quantile(.2)]['2018']

# %%
stats.ttest_ind(a=df_low2018_compare,b=df_low2019_compare,equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.598651901429536, pvalue=0.553240269431968)

# %%
# Out:
#    index      2019
# 48   VMC  0.409058
# 14    MA  0.405977
# 7    HLT  0.399774
# 26   NSC  0.343587
# 4     GE  0.320497
# 16   MAR  0.314256
# 12   KSU  0.281084
# 28   OKE  0.278993
# 38   SJM  0.241052
# 20   MET  0.211663
# 22   NEE  0.201319
# 32  PRGO  0.197284
# 46   TMK  0.193270
# 51   VTR  0.193078
# 52   WMT  0.185130
# 30   PNC  0.176669
# 36   SHW  0.176096
# 34    RE  0.172330
# 19   MCD  0.171760
# 0   FITB  0.170248
# 11   JPM  0.144698
# 3    FMC  0.132676
# 40   SLG  0.029699
# 9   INTC  0.020603
# 43   SPG -0.038604
# 24   NRG -0.070323
# 44   STT -0.113249

# %%
df_low2018_compare = df_low2018 - df['2018'].mean()

# %%
df_low2019_compare = df_lowjaccard.iloc[:,1] - df['2019'].mean()

# %%
df_low2018_compare.mean()
# Out:
# 0.0006649888624762968

# %%
(df_lowjaccard.mean() - df['2019'].mean())/df['2019'].mean()
# Out:
# 0.10234521882195527

# %%
(df_low2018.mean() - df['2018'].mean())/df['2018'].mean()
# Out:
# -0.04177853227397712

# %%
df_low2018.mean()
# Out:
# -0.015252010282333651

# %%
df['2018'].mean()
# Out:
# -0.01591699914480996

# %%
df_high2018 = df_2018[df_2018.jaccard_score>=df_2018.jaccard_score.quantile(.8)]['2018']

# %%
df_high2019 = df_2018[df_2018.jaccard_score>=df_2018.jaccard_score.quantile(.8)]['2019']

# %%
df_high2019.mean()
# Out:
# 0.03417378060141032

# %%
df['2019'].mean()
# Out:
# 0.1729856023259516

# %%
df['2018'].mean()
# Out:
# -0.01591699914480996

# %%
df['2019'].mean()
# Out:
# 0.1729856023259516

# %%
df.rename

# %%
df_lowjaccard = df_lowjaccard.reset_index().sort_values(by='2019',ascending=False)

# %%
df_lowjaccard = df_lowjaccard[df_lowjaccard.duplicated()==False]

# %%
s = ""
col = df.columns[10:22].to_list()
for i in col:
    i.replace(' ', '')
    s = s +i+'+'
s = s[:-1]

# %%
x = "".join(s.split())

# %%
col2=[]
for i in col:
    col2.append(" ".join(i.split()))
df.rename(columns=dict(zip(col,col2)), inplace=True)

# %%
df.columns[10:22]
# Out:
# Index(['Basic Industries', 'Capital Goods', 'Consumer Durables',
#        'Consumer Non-Durables', 'Consumer Services', 'Energy', 'Finance',
#        'Health Care', 'Miscellaneous', 'Public Utilities', 'Technology',
#        'Transportation'],
#       dtype='object')

# %%
y = df.jaccard_score

# %%
model = smf.ols(y).fit()
Table = sm.stats.anova_lm(model, typ=2)
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-219-95d39e7649d2> in <module>
# ----> 1 model = smf.ols(x,y).fit()
#       2 Table = sm.stats.anova_lm(model, typ=2)
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
# --> 312         raise PatsyError("model is missing required outcome variables")
#     313     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables

# %%
sns.lineplot(x = df_prices.index, y = df_prices['NRG'])
