# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
frame_list = []

# %%
df = pd.read_pickle('pickled_dfs/A.p')

# %%
df['5. adjusted close'] =  df['5. adjusted close'].astype(float)

# %%
x = df['5. adjusted close']

# %%
x.plot()
plt.show()

# %%
(df['4. close'].astype(float)).plot()
plt.show()
