# %%
import os
import functions as f
import pandas as pd
import tqdm

# %% [markdown]
# open all pickled df that have been scraped to clean

# %%
frame_list = []

# %%
for pickle in tqdm.tqdm(os.listdir('./pickled_dfs')[56:]):
    df = pd.read_pickle(f'./pickled_dfs/{pickle}')
    frame_list.append(df)
# Out:
#   0%|          | 0/443 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     147         try:
# --> 148             return func(f)
#     149         finally:
#
# ~/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/pandas/io/pickle.py in <lambda>(f)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# ...

# %%
dir_path = os.path.dirname(os.path.realpath('data_cleaning.ipynb'))
# Out:
# '/Users/matt/programming/flatiron/mod-3-project'

# %% [markdown]
# change column dtype to float

# %%
df = f.typecast_df(df)
df.head()
# Out:
#                open    high    low  close  adjusted close      volume  \
# 2019-07-12  71.8900  72.020  71.58  71.77           71.77  15347041.0
# 2019-07-11  71.4298  72.000  71.09  71.61           71.61  10739410.0
# 2019-07-10  71.5000  71.935  70.65  71.13           71.13  12153196.0
# 2019-07-09  70.5300  71.670  70.41  71.56           71.56   9477650.0
# 2019-07-08  70.7600  71.690  70.64  71.13           71.13  10196327.0
#
#             dividend amount  split coefficient symbol
# 2019-07-12              0.0                1.0      C
# 2019-07-11              0.0                1.0      C
# 2019-07-10              0.0                1.0      C
# 2019-07-09              0.0                1.0      C
# 2019-07-08              0.0                1.0      C

# %%
df = f.rearrange_cols(df)
df.head()
# Out:
#            symbol     open    high    low  close  adjusted close      volume  \
# 2019-07-12      C  71.8900  72.020  71.58  71.77           71.77  15347041.0
# 2019-07-11      C  71.4298  72.000  71.09  71.61           71.61  10739410.0
# 2019-07-10      C  71.5000  71.935  70.65  71.13           71.13  12153196.0
# 2019-07-09      C  70.5300  71.670  70.41  71.56           71.56   9477650.0
# 2019-07-08      C  70.7600  71.690  70.64  71.13           71.13  10196327.0
#
#             dividend amount  split coefficient
# 2019-07-12              0.0                1.0
# 2019-07-11              0.0                1.0
# 2019-07-10              0.0                1.0
# 2019-07-09              0.0                1.0
# 2019-07-08              0.0                1.0

# %%
df = f.date_to_column(df)
df.head()
# Out:
#          date symbol     open    high    low  close  adjusted close  \
# 0  2019-07-12      C  71.8900  72.020  71.58  71.77           71.77
# 1  2019-07-11      C  71.4298  72.000  71.09  71.61           71.61
# 2  2019-07-10      C  71.5000  71.935  70.65  71.13           71.13
# 3  2019-07-09      C  70.5300  71.670  70.41  71.56           71.56
# 4  2019-07-08      C  70.7600  71.690  70.64  71.13           71.13
#
#        volume  dividend amount  split coefficient
# 0  15347041.0              0.0                1.0
# 1  10739410.0              0.0                1.0
# 2  12153196.0              0.0                1.0
# 3   9477650.0              0.0                1.0
# 4  10196327.0              0.0                1.0
